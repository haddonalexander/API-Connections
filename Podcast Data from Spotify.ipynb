# %% [markdown]
# The intent of this exercise is to practice connecting to an API for data extraction using Python, and storing the information in a SQL database.
#
# Washed Media is a small to medium sized media company out of Austin, TX that creates a variety of podcasts published on Spotify along with other streaming apps. Let's assume they wanted to take a look at thier user engagement after each episode. There could be a variety of ways to do this, but a more user friendly way would be to import the different information sources from places like Spotify, Twitter, Instagram, Reddit etc and visualize the information in Power BI. That would allow for the data to be utilized by members of the company that do not have Python skills.
#
# One holding place for the different information sources would be a SQL database, then business intelligence applications like Power BI could connect directly to the SQL database to access the different sources of data. In order to have the different data sources compiled into a SQL database, I am setting up just one of a few data pipelines that would be necessary. This data pipeline uses Python to connect to the Spotify API. Granted, this is using my personal spotify account to access the data, so the actual data will be limited, but the general flow would be similar for a podcast owner account.

# %%
pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\haddon\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\haddon\anaconda3\lib\site-packages (from spotipy) (1.26.4)
# Requirement already satisfied: six>=1.15.0 in c:\users\haddon\anaconda3\lib\site-packages (from spotipy) (1.15.0)
# Requirement already satisfied: requests>=2.25.0 in c:\users\haddon\anaconda3\lib\site-packages (from spotipy) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\haddon\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\haddon\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\haddon\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy

# %% [markdown]
# There is an important step here that has been omitted. I established a connection with the Spotify API, but it used a private token that should not be shared publicly, so I have removed it from this demonstration.

# %% [markdown]
# Washed Media uses a different publisher for every podcast so this next part became a bit tedious.
#
# I need information about the following podcasts from Washed Media that are posted on Spotify:
#
# - Circling Back
# - Too Much Dip
# - The Mail-In Podcast
# - Sunday Scaries
# - Club Cool
# - Brunch
# - Cold Stove
# - Outgoing Without Going Out
# - Internet Party
#
# It is important to note that the following podcasts are not available on spotify, but are an important part of the Washed Media portfolio and will not be apart of this analysis.
#
# - Happy Hour Live
# - Spooky Szn
# - The Worst Of

# %% [markdown]
# Collect Washed Media Podcasts IDs

# %%
show_names = ['Circling Back', 'Too Much Dip', 'The Mail-In Podcast', 'The Sunday Scaries Podcast', 'Club Cool', 'Brunch', 'Cold Stove', 'Outgoing Without Going Out', 'Internet Party']
show_name = []
show_id = []
show_publisher = []
for name in show_names:
    for i in range(0, 10):
        shows_results = sp.search(q= name,type = 'show', market = 'US', limit=50,offset=i)
        for i, t in enumerate(shows_results['shows']['items']):
            show_name.append(t['name'])
            show_id.append(t['id'])
            show_publisher.append(t['publisher'])

# %%
import pandas as pd
show_dataframe = pd.DataFrame({'show' : show_name, 'id' : show_id, 'publisher' : show_publisher})
print(show_dataframe.shape)
show_dataframe.head()
# Out:
# (3074, 3)
#                                    show                      id  \
# 0                         Circling Back  6GWLSnyJKGMDIWsYC0RBG2
# 1                     Let's Circle Back  6nnw4nqKoBPWiEnPTuTg26
# 2  Circles Off - Sports Betting Podcast  4DxhjavM1fAdYkVw2iJI9f
# 3                           Circle Back  1TSYSNROvPh4sfpM4aV2aY
# 4               Alohomora!: Full Circle  6YE8MhfNAYX2pa0N3FNr5H
#
#                        publisher
# 0                  Circling Back
# 1              Let's Circle Back
# 2                       Betstamp
# 3  Nashville Entrepreneur Center
# 4                     Alohomora!

# %%
show_dataframe = show_dataframe[show_dataframe['show'].isin(show_names)]

# %%
show_dataframe
# Out:
#                             show                      id  \
# 0                  Circling Back  6GWLSnyJKGMDIWsYC0RBG2
# 500                 Too Much Dip  5nVfEJ9bPUvqN2ml5sUGG2
# 575          The Mail-In Podcast  2v9N3b9tVvkX06NAYwzrvU
# 1075  The Sunday Scaries Podcast  0UgblNURXpPYzoBrPHJyi1
# 1572                   Club Cool  7sH9LDMFdARFSHcZGE3R34
# 2073                      Brunch  44Cx2rZvJZvKnUlC4AU2lK
# 2074                      Brunch  2cipMvHP1DnpauVtej7ZOa
# 2076                      Brunch  36vU4yC3U19CV0L9cVvZvO
# 2122                      Brunch  44Cx2rZvJZvKnUlC4AU2lK
# 2123                      Brunch  2cipMvHP1DnpauVtej7ZOa
# 2125                      Brunch  36vU4yC3U19CV0L9cVvZvO
# 2172                      Brunch  2cipMvHP1DnpauVtej7ZOa
# 2174                      Brunch  36vU4yC3U19CV0L9cVvZvO
# 2223                      Brunch  36vU4yC3U19CV0L9cVvZvO
# 2272                      Brunch  36vU4yC3U19CV0L9cVvZvO
# 2573  Outgoing Without Going Out  7L8xnywAsJjuQcSk8PbDRc
# 2574              Internet Party  20REXE78U9IC7svf8dTrHU
#
#                        publisher
# 0                  Circling Back
# 500                 Washed Media
# 575                  The Mail-In
# 1075  The Sunday Scaries Podcast
# 1572                   Club Cool
# 2073                      BRUNCH
# 2074                   Vol Radio
# 2076                      Brunch
# 2122                      BRUNCH
# 2123                   Vol Radio
# 2125                      Brunch
# 2172                   Vol Radio
# 2174                      Brunch
# 2223                      Brunch
# 2272                      Brunch
# 2573          Gabi & Lexi Fuller
# 2574              Internet Party

# %%
show_dataframe = show_dataframe[show_dataframe['id'].isin(['6GWLSnyJKGMDIWsYC0RBG2', '5nVfEJ9bPUvqN2ml5sUGG2', '2v9N3b9tVvkX06NAYwzrvU', '0UgblNURXpPYzoBrPHJyi1', '7sH9LDMFdARFSHcZGE3R34', '44Cx2rZvJZvKnUlC4AU2lK', '7L8xnywAsJjuQcSk8PbDRc', '20REXE78U9IC7svf8dTrHU'])]

# %% [markdown]
# Just for reference, the id of the podcast appears to also be viewable if you copy and paste a podcast's URL into the search bar. It will be apart of the URL. This is how I figured out which Brunch podcast was created by Washed Media.

# %%
show_dataframe = show_dataframe.drop_duplicates(keep = 'first')

# %%
show_dataframe
# Out:
#                             show                      id  \
# 0                  Circling Back  6GWLSnyJKGMDIWsYC0RBG2
# 500                 Too Much Dip  5nVfEJ9bPUvqN2ml5sUGG2
# 575          The Mail-In Podcast  2v9N3b9tVvkX06NAYwzrvU
# 1075  The Sunday Scaries Podcast  0UgblNURXpPYzoBrPHJyi1
# 1572                   Club Cool  7sH9LDMFdARFSHcZGE3R34
# 2073                      Brunch  44Cx2rZvJZvKnUlC4AU2lK
# 2573  Outgoing Without Going Out  7L8xnywAsJjuQcSk8PbDRc
# 2574              Internet Party  20REXE78U9IC7svf8dTrHU
#
#                        publisher
# 0                  Circling Back
# 500                 Washed Media
# 575                  The Mail-In
# 1075  The Sunday Scaries Podcast
# 1572                   Club Cool
# 2073                      BRUNCH
# 2573          Gabi & Lexi Fuller
# 2574              Internet Party

# %% [markdown]
# Now that I have identified the exact podcast IDs, I am going to collect all episodes associated with each podcast.

# %%
import requests 

show_id = ['6GWLSnyJKGMDIWsYC0RBG2', '5nVfEJ9bPUvqN2ml5sUGG2', '2v9N3b9tVvkX06NAYwzrvU', '0UgblNURXpPYzoBrPHJyi1', '7sH9LDMFdARFSHcZGE3R34', '44Cx2rZvJZvKnUlC4AU2lK', '7L8xnywAsJjuQcSk8PbDRc', '20REXE78U9IC7svf8dTrHU']

for show in show_id:
    path = "https://api.spotify.com/v1/shows/" + show + "episodes"

# %%
show_ids = ['6GWLSnyJKGMDIWsYC0RBG2', '5nVfEJ9bPUvqN2ml5sUGG2', '2v9N3b9tVvkX06NAYwzrvU', '0UgblNURXpPYzoBrPHJyi1', '7sH9LDMFdARFSHcZGE3R34', '44Cx2rZvJZvKnUlC4AU2lK', '7L8xnywAsJjuQcSk8PbDRc', '20REXE78U9IC7svf8dTrHU']
show_dict = {"6GWLSnyJKGMDIWsYC0RBG2": "Circling Back", "5nVfEJ9bPUvqN2ml5sUGG2": "Too Much Dip", "2v9N3b9tVvkX06NAYwzrvU": "Mail-In", "0UgblNURXpPYzoBrPHJyi1" : "Sunday Scaries", '7sH9LDMFdARFSHcZGE3R34': 'Club Cool', "44Cx2rZvJZvKnUlC4AU2lK": "Brunch", '7L8xnywAsJjuQcSk8PbDRc': "Outgoing Without Going Out", '20REXE78U9IC7svf8dTrHU': "Internet Party"}
epi_desc = []
epi_rel_date = []
epi_duration = []
epi_resume = []
show_url = []
show_results = []

for show_id in show_ids:
    url = []
    
    for i in range(0,300,50):
        results = sp.show_episodes(show_id, market = 'US', limit=50,offset=i)
        for j in results:
            url.append(results["href"])
        for i, t in enumerate(results['items']):
            show_url.append(url[0])
            epi_desc.append(t['description'])
            epi_rel_date.append(t['release_date'])
            epi_duration.append(t["duration_ms"])

# %%
results
# Out:
# {'href': 'https://api.spotify.com/v1/shows/20REXE78U9IC7svf8dTrHU/episodes?offset=250&limit=50&market=US',
#  'items': [],
#  'limit': 50,
#  'next': None,
#  'offset': 250,
#  'previous': 'https://api.spotify.com/v1/shows/20REXE78U9IC7svf8dTrHU/episodes?offset=200&limit=50&market=US',
#  'total': 108}

# %%
epi_rel_date
# Out:
# ['2022-05-25',
#  '2022-05-23',
#  '2022-05-18',
#  '2022-05-16',
#  '2022-05-13',
#  '2022-05-11',
#  '2022-05-09',
#  '2022-05-04',
#  '2022-05-02',
#  '2022-04-27',
#  '2022-04-25',
#  '2022-04-20',
#  '2022-04-18',
#  '2022-04-13',
#  '2022-04-11',
#  '2022-04-06',
#  '2022-04-04',
#  '2022-03-30',
#  '2022-03-28',
#  '2022-03-23',
#  '2022-03-21',
#  '2022-03-16',
#  '2022-03-14',
#  '2022-03-11',
#  '2022-03-09',
#  '2022-03-07',
#  '2022-03-02',
#  '2022-02-23',
#  '2022-02-21',
#  '2022-02-16',
#  '2022-02-14',
#  '2022-02-09',
#  '2022-02-07',
#  '2022-02-02',
#  '2022-02-01',
#  '2022-01-31',
#  '2022-01-26',
#  '2022-01-24',
#  '2022-01-19',
#  '2022-01-17',
#  '2022-01-12',
#  '2022-01-10',
#  '2022-01-06',
#  '2022-01-05',
#  '2022-01-04',
#  '2022-01-03',
#  '2021-12-22',
#  '2021-12-20',
#  '2021-12-15',
#  '2021-12-13',
#  '2021-12-09',
#  '2021-12-08',
#  '2021-12-06',
#  '2021-12-02',
#  '2021-12-01',
#  '2021-11-29',
#  '2021-11-24',
#  '2021-11-23',
#  '2021-11-22',
#  '2021-11-18',
#  '2021-11-17',
#  '2021-11-15',
#  '2021-11-11',
#  '2021-11-10',
#  '2021-11-08',
#  '2021-11-04',
#  '2021-11-03',
#  '2021-11-03',
#  '2021-11-01',
#  '2021-10-28',
#  '2021-10-27',
#  '2021-10-25',
#  '2021-10-21',
#  '2021-10-20',
#  '2021-10-20',
#  '2021-10-18',
#  '2021-10-14',
#  '2021-10-13',
#  '2021-10-11',
#  '2021-10-06',
#  '2021-10-04',
#  '2021-09-29',
#  '2021-09-28',
#  '2021-09-27',
#  '2021-09-22',
#  '2021-09-20',
#  '2021-09-15',
#  '2021-09-13',
#  '2021-09-08',
#  '2021-09-07',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-08-30',
#  '2021-08-25',
#  '2021-08-23',
#  '2021-08-18',
#  '2021-08-17',
#  '2021-08-16',
#  '2021-08-11',
#  '2021-08-09',
#  '2021-08-05',
#  '2021-08-04',
#  '2021-08-02',
#  '2021-07-28',
#  '2021-07-26',
#  '2021-07-21',
#  '2021-07-19',
#  '2021-07-14',
#  '2021-07-12',
#  '2021-07-07',
#  '2021-07-05',
#  '2021-06-30',
#  '2021-06-28',
#  '2021-06-23',
#  '2021-06-21',
#  '2021-06-16',
#  '2021-06-14',
#  '2021-06-09',
#  '2021-06-09',
#  '2021-06-07',
#  '2021-06-02',
#  '2021-06-01',
#  '2021-05-26',
#  '2021-05-24',
#  '2021-05-19',
#  '2021-05-17',
#  '2021-05-12',
#  '2021-05-10',
#  '2021-05-06',
#  '2021-05-05',
#  '2021-05-03',
#  '2021-04-28',
#  '2021-04-26',
#  '2021-04-22',
#  '2021-04-19',
#  '2021-04-14',
#  '2021-04-12',
#  '2021-04-07',
#  '2021-04-06',
#  '2021-04-05',
#  '2021-04-01',
#  '2021-03-31',
#  '2021-03-29',
#  '2021-03-24',
#  '2021-03-23',
#  '2021-03-22',
#  '2021-03-17',
#  '2021-03-15',
#  '2021-03-10',
#  '2021-03-08',
#  '2021-03-04',
#  '2021-03-03',
#  '2021-03-02',
#  '2021-03-01',
#  '2021-02-24',
#  '2021-02-22',
#  '2021-02-17',
#  '2021-02-10',
#  '2021-02-08',
#  '2021-02-03',
#  '2021-02-02',
#  '2021-02-01',
#  '2021-01-27',
#  '2021-01-25',
#  '2021-01-20',
#  '2021-01-18',
#  '2021-01-13',
#  '2021-01-11',
#  '2021-01-06',
#  '2021-01-05',
#  '2021-01-04',
#  '2020-12-21',
#  '2020-12-16',
#  '2020-12-14',
#  '2020-12-09',
#  '2020-12-07',
#  '2020-12-02',
#  '2020-11-30',
#  '2020-11-23',
#  '2020-11-18',
#  '2020-11-16',
#  '2020-11-11',
#  '2020-11-09',
#  '2020-11-04',
#  '2020-11-02',
#  '2020-10-28',
#  '2020-10-26',
#  '2020-10-21',
#  '2020-10-19',
#  '2020-10-14',
#  '2020-10-14',
#  '2020-10-12',
#  '2020-10-07',
#  '2020-10-05',
#  '2020-09-30',
#  '2020-09-28',
#  '2020-09-23',
#  '2020-09-22',
#  '2020-09-21',
#  '2020-09-16',
#  '2020-09-14',
#  '2020-09-09',
#  '2020-09-07',
#  '2020-09-02',
#  '2020-08-31',
#  '2020-08-26',
#  '2020-08-24',
#  '2020-08-19',
#  '2020-08-17',
#  '2020-08-12',
#  '2020-08-10',
#  '2020-08-05',
#  '2020-08-03',
#  '2020-07-29',
#  '2020-07-27',
#  '2020-07-22',
#  '2020-07-20',
#  '2020-07-15',
#  '2020-07-13',
#  '2020-07-08',
#  '2020-07-06',
#  '2020-07-01',
#  '2020-06-29',
#  '2020-06-24',
#  '2020-06-22',
#  '2020-06-17',
#  '2020-06-15',
#  '2020-06-10',
#  '2020-06-08',
#  '2020-06-03',
#  '2020-06-01',
#  '2020-05-27',
#  '2020-05-25',
#  '2020-05-20',
#  '2020-05-18',
#  '2020-05-13',
#  '2020-05-11',
#  '2020-05-06',
#  '2020-05-04',
#  '2020-04-29',
#  '2020-04-27',
#  '2020-04-22',
#  '2020-04-20',
#  '2020-04-15',
#  '2020-04-13',
#  '2020-04-08',
#  '2020-04-06',
#  '2020-04-01',
#  '2020-03-30',
#  '2020-03-25',
#  '2020-03-23',
#  '2020-03-18',
#  '2020-03-16',
#  '2020-03-11',
#  '2020-03-09',
#  '2020-03-04',
#  '2020-03-02',
#  '2020-02-27',
#  '2020-02-26',
#  '2020-02-24',
#  '2020-02-19',
#  '2020-02-17',
#  '2020-02-12',
#  '2020-02-10',
#  '2020-02-05',
#  '2020-02-03',
#  '2020-01-29',
#  '2020-01-27',
#  '2020-01-22',
#  '2020-01-20',
#  '2020-01-15',
#  '2020-01-13',
#  '2020-01-08',
#  '2020-01-07',
#  '2020-01-06',
#  '2019-12-30',
#  '2019-12-23',
#  '2019-12-18',
#  '2019-12-16',
#  '2019-12-11',
#  '2019-12-09',
#  '2019-12-04',
#  '2019-12-02',
#  '2019-11-27',
#  '2019-11-25',
#  '2019-11-20',
#  '2019-11-18',
#  '2019-11-13',
#  '2019-11-12',
#  '2019-11-11',
#  '2019-11-06',
#  '2019-11-04',
#  '2019-10-30',
#  '2019-10-28',
#  '2019-10-23',
#  '2019-10-21',
#  '2019-10-16',
#  '2019-10-14',
#  '2019-10-09',
#  '2019-10-07',
#  '2022-05-23',
#  '2022-05-16',
#  '2022-05-09',
#  '2022-05-02',
#  '2022-04-25',
#  '2022-04-18',
#  '2022-04-11',
#  '2022-04-04',
#  '2022-03-28',
#  '2022-03-21',
#  '2022-03-14',
#  '2022-03-07',
#  '2022-03-01',
#  '2022-02-21',
#  '2022-02-14',
#  '2022-02-11',
#  '2022-02-07',
#  '2022-02-04',
#  '2022-01-31',
#  '2022-01-28',
#  '2022-01-24',
#  '2022-01-21',
#  '2022-01-17',
#  '2022-01-14',
#  '2022-01-10',
#  '2022-01-07',
#  '2022-01-03',
#  '2021-12-20',
#  '2021-12-17',
#  '2021-12-13',
#  '2021-12-10',
#  '2021-12-06',
#  '2021-12-03',
#  '2021-11-29',
#  '2021-11-22',
#  '2021-11-19',
#  '2021-11-15',
#  '2021-11-12',
#  '2021-11-08',
#  '2021-11-05',
#  '2021-11-01',
#  '2021-10-29',
#  '2021-10-25',
#  '2021-10-22',
#  '2021-10-18',
#  '2021-10-15',
#  '2021-10-11',
#  '2021-10-08',
#  '2021-10-04',
#  '2021-10-01',
#  '2021-09-27',
#  '2021-09-24',
#  '2021-09-20',
#  '2021-09-17',
#  '2021-09-13',
#  '2021-09-09',
#  '2021-09-07',
#  '2021-08-30',
#  '2021-08-23',
#  '2021-08-16',
#  '2021-08-09',
#  '2021-08-02',
#  '2021-07-26',
#  '2021-07-19',
#  '2021-07-12',
#  '2021-07-06',
#  '2021-06-28',
#  '2021-06-21',
#  '2021-06-18',
#  '2021-06-14',
#  '2021-06-07',
#  '2021-06-01',
#  '2021-05-24',
#  '2021-05-17',
#  '2021-05-10',
#  '2021-05-03',
#  '2021-04-26',
#  '2021-04-19',
#  '2021-04-12',
#  '2021-04-05',
#  '2021-03-29',
#  '2021-03-22',
#  '2021-03-15',
#  '2021-03-08',
#  '2021-03-01',
#  '2021-02-22',
#  '2021-02-19',
#  '2021-02-08',
#  '2021-02-05',
#  '2021-02-01',
#  '2021-01-29',
#  '2021-01-25',
#  '2021-01-22',
#  '2021-01-18',
#  '2021-01-15',
#  '2021-01-11',
#  '2021-01-08',
#  '2021-01-04',
#  '2020-12-21',
#  '2020-12-18',
#  '2020-12-14',
#  '2020-12-11',
#  '2020-12-07',
#  '2020-12-04',
#  '2020-11-30',
#  '2020-11-23',
#  '2020-11-20',
#  '2020-11-17',
#  '2020-11-13',
#  '2020-11-09',
#  '2020-11-06',
#  '2020-11-02',
#  '2020-10-30',
#  '2020-10-26',
#  '2020-10-23',
#  '2020-10-19',
#  '2020-10-16',
#  '2020-10-12',
#  '2020-10-09',
#  '2020-10-05',
#  '2020-10-02',
#  '2020-09-28',
#  '2020-09-25',
#  '2020-09-21',
#  '2020-09-18',
#  '2020-09-14',
#  '2020-09-11',
#  '2020-09-07',
#  '2020-08-31',
#  '2020-08-24',
#  '2020-08-17',
#  '2020-08-10',
#  '2020-08-03',
#  '2020-07-29',
#  '2020-07-24',
#  '2022-05-19',
#  '2022-05-12',
#  '2022-05-05',
#  '2022-04-28',
#  '2022-04-21',
#  '2022-04-14',
#  '2022-04-07',
#  '2022-03-31',
#  '2022-03-24',
#  '2022-03-17',
#  '2022-03-10',
#  '2022-03-03',
#  '2022-02-24',
#  '2022-02-17',
#  '2022-02-10',
#  '2022-02-03',
#  '2022-01-27',
#  '2022-01-20',
#  '2022-01-13',
#  '2022-01-06',
#  '2021-12-23',
#  '2021-12-16',
#  '2021-12-09',
#  '2021-12-02',
#  '2021-11-18',
#  '2021-11-11',
#  '2021-11-04',
#  '2021-10-28',
#  '2021-10-21',
#  '2021-10-14',
#  '2021-10-07',
#  '2021-09-30',
#  '2021-09-23',
#  '2021-09-17',
#  '2021-09-09',
#  '2021-09-02',
#  '2021-08-27',
#  '2021-08-19',
#  '2021-08-13',
#  '2021-08-05',
#  '2021-07-29',
#  '2021-07-22',
#  '2021-07-08',
#  '2021-07-01',
#  '2021-06-24',
#  '2021-06-17',
#  '2021-06-10',
#  '2021-06-03',
#  '2021-05-27',
#  '2021-05-20',
#  '2021-05-13',
#  '2021-05-06',
#  '2021-04-29',
#  '2021-04-22',
#  '2021-04-15',
#  '2021-04-08',
#  '2021-04-01',
#  '2021-03-25',
#  '2021-03-18',
#  '2021-03-11',
#  '2021-03-04',
#  '2021-02-25',
#  '2021-02-18',
#  '2021-02-11',
#  '2021-02-04',
#  '2021-01-28',
#  '2021-01-21',
#  '2021-01-14',
#  '2021-01-07',
#  '2020-12-17',
#  '2020-12-10',
#  '2020-12-03',
#  '2020-11-19',
#  '2020-11-12',
#  '2020-11-05',
#  '2020-10-29',
#  '2020-10-22',
#  '2020-10-15',
#  '2020-10-08',
#  '2020-09-24',
#  '2020-09-17',
#  '2020-09-10',
#  '2020-09-03',
#  '2020-08-27',
#  '2020-08-20',
#  '2020-08-13',
#  '2020-08-06',
#  '2020-07-30',
#  '2020-07-23',
#  '2020-07-16',
#  '2020-07-09',
#  '2020-07-02',
#  '2020-06-25',
#  '2020-06-18',
#  '2020-06-11',
#  '2020-06-04',
#  '2020-05-28',
#  '2020-05-21',
#  '2020-05-14',
#  '2020-05-07',
#  '2020-04-30',
#  '2020-04-23',
#  '2020-04-16',
#  '2020-04-09',
#  '2020-04-02',
#  '2020-03-26',
#  '2020-03-19',
#  '2020-03-12',
#  '2020-03-05',
#  '2020-02-27',
#  '2020-02-20',
#  '2020-02-13',
#  '2020-02-06',
#  '2020-01-30',
#  '2020-01-23',
#  '2020-01-16',
#  '2020-01-09',
#  '2019-12-24',
#  '2019-12-19',
#  '2019-12-12',
#  '2019-12-05',
#  '2019-11-21',
#  '2019-11-14',
#  '2019-11-07',
#  '2019-10-31',
#  '2019-10-24',
#  '2019-10-17',
#  '2019-10-10',
#  '2019-10-03',
#  '2019-09-26',
#  '2019-09-12',
#  '2019-09-05',
#  '2019-08-29',
#  '2019-08-22',
#  '2019-08-15',
#  '2019-08-08',
#  '2019-08-01',
#  '2019-07-24',
#  '2019-07-18',
#  '2019-07-11',
#  '2019-06-27',
#  '2019-06-20',
#  '2019-06-13',
#  '2019-06-06',
#  '2019-05-30',
#  '2019-05-23',
#  '2019-05-16',
#  '2019-05-09',
#  '2019-04-30',
#  '2019-04-17',
#  '2019-04-10',
#  '2019-04-03',
#  '2019-03-20',
#  '2019-03-13',
#  '2019-03-06',
#  '2019-02-27',
#  '2019-02-20',
#  '2019-02-13',
#  '2019-02-06',
#  '2019-01-30',
#  '2019-01-23',
#  '2022-05-27',
#  '2022-05-25',
#  '2022-05-22',
#  '2022-05-18',
#  '2022-05-15',
#  '2022-05-11',
#  '2022-05-08',
#  '2022-05-01',
#  '2022-04-27',
#  '2022-04-24',
#  '2022-04-17',
#  '2022-04-10',
#  '2022-04-03',
#  '2022-03-30',
#  '2022-03-27',
#  '2022-03-20',
#  '2022-03-16',
#  '2022-03-13',
#  '2022-03-06',
#  '2022-03-02',
#  '2022-02-27',
#  '2022-02-23',
#  '2022-02-20',
#  '2022-02-13',
#  '2022-02-06',
#  '2022-02-02',
#  '2022-01-30',
#  '2022-01-23',
#  '2022-01-16',
#  '2022-01-09',
#  '2021-12-19',
#  '2021-12-12',
#  '2021-12-05',
#  '2021-11-28',
#  '2021-11-21',
#  '2021-11-14',
#  '2021-11-07',
#  '2021-10-31',
#  '2021-10-24',
#  '2021-10-17',
#  '2021-10-10',
#  '2021-10-03',
#  '2021-09-26',
#  '2021-09-19',
#  '2021-09-12',
#  '2021-09-12',
#  '2021-09-05',
#  '2021-08-29',
#  '2021-08-22',
#  '2021-08-15',
#  '2021-08-08',
#  '2021-08-01',
#  '2021-07-25',
#  '2021-07-18',
#  '2021-07-11',
#  '2021-07-04',
#  '2021-06-27',
#  '2021-06-20',
#  '2021-06-13',
#  '2021-06-06',
#  '2021-05-30',
#  '2021-05-23',
#  '2021-05-16',
#  '2021-05-09',
#  '2021-05-02',
#  '2021-04-25',
#  '2021-04-18',
#  '2021-04-11',
#  '2021-04-04',
#  '2021-03-28',
#  '2021-03-21',
#  '2021-03-14',
#  '2021-03-07',
#  '2021-02-28',
#  '2021-02-21',
#  '2021-02-14',
#  '2021-02-07',
#  '2021-01-31',
#  '2021-01-24',
#  '2021-01-17',
#  '2021-01-10',
#  '2021-01-03',
#  '2020-12-20',
#  '2020-12-13',
#  '2020-12-06',
#  '2020-11-29',
#  '2020-11-22',
#  '2020-11-15',
#  '2020-11-08',
#  '2020-11-01',
#  '2020-10-25',
#  '2020-10-17',
#  '2020-10-11',
#  '2020-10-04',
#  '2020-09-27',
#  '2020-09-20',
#  '2020-09-13',
#  '2020-09-06',
#  '2020-08-30',
#  '2020-08-23',
#  '2020-08-16',
#  '2020-08-09',
#  '2020-08-02',
#  '2020-07-19',
#  '2020-07-12',
#  '2020-07-05',
#  '2020-06-28',
#  '2020-06-21',
#  '2020-06-14',
#  '2020-06-07',
#  '2020-05-31',
#  '2020-05-24',
#  '2020-05-17',
#  '2020-05-10',
#  '2020-05-03',
#  '2020-04-26',
#  '2020-04-19',
#  '2020-04-12',
#  '2020-04-05',
#  '2020-03-29',
#  '2020-03-22',
#  '2020-03-15',
#  '2020-03-08',
#  '2020-03-01',
#  '2020-02-23',
#  '2020-02-16',
#  '2020-02-09',
#  '2020-02-02',
#  '2020-01-26',
#  '2020-01-19',
#  '2020-01-12',
#  '2019-12-29',
#  '2019-12-22',
#  '2019-12-15',
#  '2019-12-08',
#  '2019-12-01',
#  '2019-11-24',
#  '2019-11-17',
#  '2019-11-10',
#  '2019-11-03',
#  '2019-10-27',
#  '2019-10-20',
#  '2019-10-13',
#  '2019-10-06',
#  '2019-09-29',
#  '2019-09-22',
#  '2019-09-15',
#  '2019-09-08',
#  '2019-09-01',
#  '2019-08-25',
#  '2019-08-18',
#  '2019-08-07',
#  '2019-08-04',
#  '2019-07-28',
#  '2019-07-21',
#  '2019-07-14',
#  '2019-07-07',
#  '2019-06-30',
#  '2019-06-23',
#  '2019-06-16',
#  '2019-06-09',
#  '2019-06-02',
#  '2019-05-26',
#  '2019-05-19',
#  '2019-05-12',
#  '2019-05-05',
#  '2019-04-28',
#  '2019-04-21',
#  '2019-04-14',
#  '2019-04-07',
#  '2019-03-31',
#  '2019-03-24',
#  '2019-03-17',
#  '2019-03-10',
#  '2019-03-03',
#  '2019-02-24',
#  '2019-02-19',
#  '2019-02-17',
#  '2019-02-10',
#  '2019-02-03',
#  '2019-01-27',
#  '2019-01-20',
#  '2019-01-13',
#  '2019-01-06',
#  '2019-01-01',
#  '2018-12-23',
#  '2018-12-15',
#  '2018-12-09',
#  '2018-12-02',
#  '2018-11-25',
#  '2018-11-16',
#  '2018-11-11',
#  '2018-11-04',
#  '2018-10-28',
#  '2018-10-21',
#  '2018-10-14',
#  '2018-10-07',
#  '2018-09-28',
#  '2018-09-23',
#  '2018-09-16',
#  '2018-09-09',
#  '2018-09-02',
#  '2018-08-26',
#  '2018-08-19',
#  '2018-08-12',
#  '2018-08-05',
#  '2018-07-29',
#  '2018-07-22',
#  '2018-07-15',
#  '2018-07-11',
#  '2018-07-08',
#  '2018-06-30',
#  '2018-06-30',
#  '2018-06-30',
#  '2018-06-30',
#  '2018-06-28',
#  '2022-05-14',
#  '2022-05-07',
#  '2022-05-01',
#  '2022-04-07',
#  '2022-03-26',
#  '2022-03-12',
#  '2022-02-26',
#  '2022-02-03',
#  '2022-01-31',
#  '2022-01-20',
#  '2022-01-12',
#  '2022-01-08',
#  '2021-12-18',
#  '2021-12-11',
#  '2021-12-04',
#  '2021-11-20',
#  '2021-10-29',
#  '2021-10-22',
#  '2021-10-14',
#  '2021-10-08',
#  '2021-10-01',
#  '2021-09-23',
#  '2021-09-17',
#  '2021-09-09',
#  '2021-09-02',
#  '2021-08-27',
#  '2021-08-12',
#  '2021-08-05',
#  '2021-07-22',
#  '2021-07-15',
#  '2021-07-01',
#  '2021-06-24',
#  '2021-06-17',
#  '2021-06-03',
#  '2021-05-27',
#  '2021-05-20',
#  '2021-05-06',
#  '2021-04-29',
#  '2021-04-23',
#  '2021-04-16',
#  '2021-04-08',
#  '2021-04-01',
#  '2021-03-25',
#  '2021-03-18',
#  '2021-03-11',
#  '2021-03-04',
#  '2021-02-25',
#  '2021-02-10',
#  '2021-02-03',
#  '2021-01-21',
#  '2021-01-14',
#  '2021-01-08',
#  '2020-12-24',
#  '2020-12-18',
#  '2020-12-11',
#  '2020-12-04',
#  '2020-11-25',
#  '2020-11-20',
#  '2020-11-13',
#  '2020-11-04',
#  '2020-10-30',
#  '2020-10-23',
#  '2020-10-16',
#  '2020-10-08',
#  '2020-10-01',
#  '2020-09-25',
#  '2020-09-18',
#  '2020-09-11',
#  '2020-08-31',
#  '2020-08-24',
#  '2020-08-17',
#  '2020-08-14',
#  '2020-08-05',
#  '2020-07-30',
#  '2020-07-24',
#  '2020-07-17',
#  '2020-07-10',
#  '2020-06-26',
#  '2020-06-18',
#  '2020-06-12',
#  '2020-05-29',
#  '2020-05-22',
#  '2020-05-15',
#  '2020-05-08',
#  '2020-05-01',
#  '2020-04-26',
#  '2020-04-18',
#  '2020-04-11',
#  '2020-04-03',
#  '2020-03-26',
#  '2020-03-19',
#  '2020-03-12',
#  '2020-03-05',
#  '2020-02-21',
#  '2020-02-14',
#  '2020-02-07',
#  '2020-01-31',
#  '2020-01-23',
#  '2020-01-16',
#  '2020-01-10',
#  '2019-12-19',
#  '2019-12-12',
#  '2019-12-05',
#  '2019-11-21',
#  '2019-11-14',
#  '2019-11-02',
#  '2019-10-24',
#  '2019-10-17',
#  '2019-10-11',
#  '2019-10-03',
#  '2019-09-26',
#  '2019-09-13',
#  '2019-09-06',
#  '2019-08-23',
#  '2019-08-15',
#  '2019-08-02',
#  '2019-07-25',
#  '2019-07-11',
#  '2019-07-03',
#  '2019-06-27',
#  '2019-06-10',
#  '2019-06-05',
#  '2019-05-29',
#  '2019-05-22',
#  '2019-05-15',
#  '2019-05-08',
#  '2019-05-01',
#  '2019-04-24',
#  '2019-04-19',
#  '2019-04-10',
#  '2019-04-03',
#  '2019-03-27',
#  '2019-03-20',
#  '2019-03-13',
#  '2019-03-06',
#  '2019-02-27',
#  '2019-02-21',
#  '2019-02-13',
#  '2019-02-06',
#  '2019-01-30',
#  '2019-01-23',
#  '2019-01-16',
#  '2019-01-04',
#  '2018-12-19',
#  '2018-12-12',
#  '2018-11-07',
#  '2018-10-31',
#  '2018-10-24',
#  '2018-10-17',
#  '2018-10-10',
#  '2018-10-03',
#  '2018-09-26',
#  '2018-09-19',
#  '2018-09-12',
#  '2018-09-11',
#  '2018-09-11',
#  '2018-09-11',
#  '2018-09-11',
#  '2018-09-11',
#  '2018-09-11',
#  '2018-09-11',
#  '2018-09-11',
#  '2018-09-11',
#  '2018-09-11',
#  '2018-09-11',
#  '2022-05-25',
#  '2022-05-20',
#  '2022-05-12',
#  '2022-05-04',
#  '2022-04-25',
#  '2022-04-20',
#  '2022-04-13',
#  '2022-04-06',
#  '2022-03-29',
#  '2022-03-29',
#  '2022-03-29',
#  '2022-03-29',
#  '2022-03-29',
#  '2022-03-29',
#  '2022-03-29',
#  '2022-03-29',
#  '2022-03-29',
#  '2022-03-29',
#  '2022-03-28',
#  '2022-03-23',
#  '2022-03-17',
#  '2022-03-09',
#  '2022-03-02',
#  ...]

# %%
len(epi_rel_date)
# Out:
# 1509

# %%
len(show_url)
# Out:
# 1509

# %%
len(epi_desc)
# Out:
# 1509

# %%
len(epi_duration)
# Out:
# 1509

# %%
df = pd.DataFrame({"Description": epi_desc, "Date": epi_rel_date, "Duration": epi_duration, "Url": show_url})

# %%
df
# Out:
#                                             Description        Date  Duration  \
# 0     Seth Green's NFTs got stolen because that's wh...  2022-05-25   3957983
# 1     In the aftermath of H Week, we had no choice b...  2022-05-23   4044000
# 2     H Week rolls on which left us no choice but to...  2022-05-18   4459128
# 3     Did Dave get in a drive-thru altercation? Yes....  2022-05-16   4211880
# 4     Another Friday, another pot of coffee, another...  2022-05-13   3860711
# ...                                                 ...         ...       ...
# 1504  the boys are back on the sauce so you know thi...  2019-02-05   2038073
# 1505  the squadron sits down on a snowy january even...  2019-01-28   2702054
# 1506  brad and john talk soulja boy and his influenc...  2019-01-25   1140062
# 1507  brad and john discuss their childhoods and tou...  2019-01-21   2474057
# 1508  an introduction to internet party. john duda a...  2019-01-13   2970070
#
#                                                     Url
# 0     https://api.spotify.com/v1/shows/6GWLSnyJKGMDI...
# 1     https://api.spotify.com/v1/shows/6GWLSnyJKGMDI...
# 2     https://api.spotify.com/v1/shows/6GWLSnyJKGMDI...
# 3     https://api.spotify.com/v1/shows/6GWLSnyJKGMDI...
# 4     https://api.spotify.com/v1/shows/6GWLSnyJKGMDI...
# ...                                                 ...
# 1504  https://api.spotify.com/v1/shows/20REXE78U9IC7...
# 1505  https://api.spotify.com/v1/shows/20REXE78U9IC7...
# 1506  https://api.spotify.com/v1/shows/20REXE78U9IC7...
# 1507  https://api.spotify.com/v1/shows/20REXE78U9IC7...
# 1508  https://api.spotify.com/v1/shows/20REXE78U9IC7...
#
# [1509 rows x 4 columns]

# %%
df["Url"][500]
# Out:
# 'https://api.spotify.com/v1/shows/2v9N3b9tVvkX06NAYwzrvU/episodes?offset=0&limit=50&market=US'

# %%
show_ids
# Out:
# ['6GWLSnyJKGMDIWsYC0RBG2',
#  '5nVfEJ9bPUvqN2ml5sUGG2',
#  '2v9N3b9tVvkX06NAYwzrvU',
#  '0UgblNURXpPYzoBrPHJyi1',
#  '7sH9LDMFdARFSHcZGE3R34',
#  '44Cx2rZvJZvKnUlC4AU2lK',
#  '7L8xnywAsJjuQcSk8PbDRc',
#  '20REXE78U9IC7svf8dTrHU']

# %%
urls = df["Url"].unique()

# %%
url_shows = {}

for url in urls:
    for show_id in show_dict:
        if show_id in url:
            url_shows[url] = show_dict[show_id]

# %%
url_shows
# Out:
# {'https://api.spotify.com/v1/shows/6GWLSnyJKGMDIWsYC0RBG2/episodes?offset=0&limit=50&market=US': 'Circling Back',
#  'https://api.spotify.com/v1/shows/5nVfEJ9bPUvqN2ml5sUGG2/episodes?offset=0&limit=50&market=US': 'Too Much Dip',
#  'https://api.spotify.com/v1/shows/2v9N3b9tVvkX06NAYwzrvU/episodes?offset=0&limit=50&market=US': 'Mail-In',
#  'https://api.spotify.com/v1/shows/0UgblNURXpPYzoBrPHJyi1/episodes?offset=0&limit=50&market=US': 'Sunday Scaries',
#  'https://api.spotify.com/v1/shows/7sH9LDMFdARFSHcZGE3R34/episodes?offset=0&limit=50&market=US': 'Club Cool',
#  'https://api.spotify.com/v1/shows/44Cx2rZvJZvKnUlC4AU2lK/episodes?offset=0&limit=50&market=US': 'Brunch',
#  'https://api.spotify.com/v1/shows/7L8xnywAsJjuQcSk8PbDRc/episodes?offset=0&limit=50&market=US': 'Outgoing Without Going Out',
#  'https://api.spotify.com/v1/shows/20REXE78U9IC7svf8dTrHU/episodes?offset=0&limit=50&market=US': 'Internet Party'}

# %%
df["Url"] = df["Url"].replace(url_shows)

# %%
df.rename(columns = {"Url" : "Name"}, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1509 entries, 0 to 1508
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Description  1509 non-null   object
#  1   Date         1509 non-null   object
#  2   Duration     1509 non-null   int64
#  3   Name         1509 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 47.3+ KB

# %%
df["Duration"] = df["Duration"]/ 60000

# %%
df
# Out:
#                                             Description        Date  \
# 0     Seth Green's NFTs got stolen because that's wh...  2022-05-25
# 1     In the aftermath of H Week, we had no choice b...  2022-05-23
# 2     H Week rolls on which left us no choice but to...  2022-05-18
# 3     Did Dave get in a drive-thru altercation? Yes....  2022-05-16
# 4     Another Friday, another pot of coffee, another...  2022-05-13
# ...                                                 ...         ...
# 1504  the boys are back on the sauce so you know thi...  2019-02-05
# 1505  the squadron sits down on a snowy january even...  2019-01-28
# 1506  brad and john talk soulja boy and his influenc...  2019-01-25
# 1507  brad and john discuss their childhoods and tou...  2019-01-21
# 1508  an introduction to internet party. john duda a...  2019-01-13
#
#        Duration            Name
# 0     65.966383   Circling Back
# 1     67.400000   Circling Back
# 2     74.318800   Circling Back
# 3     70.198000   Circling Back
# 4     64.345183   Circling Back
# ...         ...             ...
# 1504  33.967883  Internet Party
# 1505  45.034233  Internet Party
# 1506  19.001033  Internet Party
# 1507  41.234283  Internet Party
# 1508  49.501167  Internet Party
#
# [1509 rows x 4 columns]

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Day"] = df["Date"].dt.day_name()

# %%
df
# Out:
#                                             Description       Date   Duration  \
# 0     Seth Green's NFTs got stolen because that's wh... 2022-05-25  65.966383
# 1     In the aftermath of H Week, we had no choice b... 2022-05-23  67.400000
# 2     H Week rolls on which left us no choice but to... 2022-05-18  74.318800
# 3     Did Dave get in a drive-thru altercation? Yes.... 2022-05-16  70.198000
# 4     Another Friday, another pot of coffee, another... 2022-05-13  64.345183
# ...                                                 ...        ...        ...
# 1504  the boys are back on the sauce so you know thi... 2019-02-05  33.967883
# 1505  the squadron sits down on a snowy january even... 2019-01-28  45.034233
# 1506  brad and john talk soulja boy and his influenc... 2019-01-25  19.001033
# 1507  brad and john discuss their childhoods and tou... 2019-01-21  41.234283
# 1508  an introduction to internet party. john duda a... 2019-01-13  49.501167
#
#                 Name        Day
# 0      Circling Back  Wednesday
# 1      Circling Back     Monday
# 2      Circling Back  Wednesday
# 3      Circling Back     Monday
# 4      Circling Back     Friday
# ...              ...        ...
# 1504  Internet Party    Tuesday
# 1505  Internet Party     Monday
# 1506  Internet Party     Friday
# 1507  Internet Party     Monday
# 1508  Internet Party     Sunday
#
# [1509 rows x 5 columns]

# %%
df["Name"].value_counts()
# Out:
# Circling Back                 300
# Brunch                        300
# Sunday Scaries                216
# Club Cool                     165
# Mail-In                       161
# Too Much Dip                  135
# Outgoing Without Going Out    124
# Internet Party                108
# Name: Name, dtype: int64

# %%
import csv 
import sqlite3

connection = sqlite3.connect(r"C:\Users\Haddon\washedmedia.db")

cursor = connection.cursor()

drop_table = "DROP TABLE IF EXISTS washed_media_episodes"

create_table =   '''CREATE TABLE IF NOT EXISTS washed_media_episodes(
                    id INTEGER PRIMARY KEY AUTOINCREMENT,
                    description TEXT,
                    date DATETIME,
                    duration FLOAT,
                    name TEXT,
                    day TEXT)
                    '''

cursor.execute(drop_table)

cursor.execute(create_table)

df.to_sql('washed_media_episodes', connection, if_exists='replace', index = False)
